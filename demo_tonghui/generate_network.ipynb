# %% [markdown]
# 生成一个网络

# %%
from pathlib import Path
import pytest
from gnpy.core.exceptions import NetworkTopologyError
from gnpy.core.network import span_loss
from gnpy.tools.json_io import load_equipment, load_network



EQPT_FILENAME = 'eqpt_config.json'
NETWORK_FILENAME = 'bugfixiteratortopo.json'

# %%
equipment = load_equipment(EQPT_FILENAME)
network = load_network(NETWORK_FILENAME, equipment)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\44894\OneDrive\Coding\Python\oopt-gnpy\demo_tonghui\generate_network.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/44894/OneDrive/Coding/Python/oopt-gnpy/demo_tonghui/generate_network.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> equipment = load_equipment(EQPT_FILENAME)
#       <a href='vscode-notebook-cell:/c%3A/Users/44894/OneDrive/Coding/Python/oopt-gnpy/demo_tonghui/generate_network.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> network = load_network(NETWORK_FILENAME, equipment)
#
# File ~\OneDrive\Coding\Python\oopt-gnpy\gnpy\tools\json_io.py:343, in load_equipment(filename)
#     341 def load_equipment(filename):
#     342     json_data = load_json(filename)
# --> 343     return _equipment_from_json(json_data, filename)
#
# File ~\OneDrive\Coding\Python\oopt-gnpy\gnpy\tools\json_io.py:411, in _equipment_from_json(json_data, filename)
#     409 subkey = entry.get('type_variety', 'default')
#     410 if key == 'Edfa':
# --> 411     equipment[key][subkey] = Amp.from_json(filename, **entry)
#     412 elif key == 'Fiber':
#     413     equipment[key][subkey] = Fiber(**entry)
#
# File ~\OneDrive\Coding\Python\oopt-gnpy\gnpy\tools\json_io.py:254, in Amp.from_json(cls, filename, **kwargs)
#     251 else:
#     252     raise EquipmentConfigError(f'Edfa type_def {type_def} does not exist')
# --> 254 json_data = load_json(config)
#     256 return cls(**{**kwargs, **json_data,
#     257               'nf_model': nf_def, 'dual_stage_model': dual_stage_def})
#
# File ~\OneDrive\Coding\Python\oopt-gnpy\gnpy\tools\json_io.py:530, in load_json(filename)
#     529 def load_json(filename):
# --> 530     with open(filename, 'r', encoding='utf-8') as f:
#     531         data = json.load(f)
#     532     return data
#
# FileNotFoundError: [Errno 2] No such file or directory: 'std_medium_gain_advanced_config.json'
